# %% [markdown]
# ### Transforming The Oscars Dataset for SQL work

# %% [markdown]
# How to clean a CSV dataset and add it to a SQLite database.

# %% [markdown]
# ![alt text](http://bensbargains.com/thecheckout/wp-content/uploads/2016/02/leo-oscars.jpg "The Oscars")

# %% [markdown]
# The Academy Awards, also known as the Oscars, is an annual awards ceremony hosted to recognize the achievements in the film industry. There are many different awards categories and the members of the academy vote every year to decide which artist or film should get the award.

# %% [markdown]
# ### Import the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
academy_awards = pd.read_csv("academy_awards.csv", encoding = "ISO-8859-1")

# %%
academy_awards.columns
# Out:
# Index(['Year', 'Category', 'Nominee', 'Additional Info', 'Won?', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %% [markdown]
# **Column Description**:
#
# **Year** - the year of the awards ceremony.
#
# **Category** - the category of award the nominee was nominated for.
#
# **Nominee** - the person nominated for the award.
#
# **Additional Info** - this column contains additional info like:
#
# 1. the movie the nominee participated in.
# 2. the character the nominee played (for acting awards).
#
# **Won?** - this column contains either YES or NO depending on if the nominee won the award.

# %%
academy_awards.head()
# Out:
#           Year               Category          Nominee  \
# 0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                           Additional Info Won? Unnamed: 5 Unnamed: 6  \
# 0                      Biutiful {'Uxbal'}   NO        NaN        NaN
# 1           True Grit {'Rooster Cogburn'}   NO        NaN        NaN
# 2  The Social Network {'Mark Zuckerberg'}   NO        NaN        NaN
# 3    The King's Speech {'King George VI'}  YES        NaN        NaN
# 4              127 Hours {'Aron Ralston'}   NO        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN         NaN

# %%
academy_awards.shape
# Out:
# (10137, 11)

# %%
ac_aw_col_nullcount = {}
academy_awards_cols = academy_awards.columns.tolist()
for col in academy_awards_cols:
    ac_aw_col_nullcount[col] = len(academy_awards[academy_awards[col].isnull()])
ac_aw_col_nullcount
# Out:
# {'Additional Info': 1126,
#  'Category': 0,
#  'Nominee': 0,
#  'Unnamed: 10': 10136,
#  'Unnamed: 5': 10126,
#  'Unnamed: 6': 10125,
#  'Unnamed: 7': 10134,
#  'Unnamed: 8': 10135,
#  'Unnamed: 9': 10136,
#  'Won?': 0,
#  'Year': 0}

# %%
plt.bar(range(0,len(ac_aw_col_nullcount)),list(ac_aw_col_nullcount.values()))
plt.xticks(range(0,12),list(ac_aw_col_nullcount.keys()), rotation = 50)
plt.xlabel("Features")
#plt.xticklabel()
plt.ylabel("Null Count")
plt.title("Null Count of the Dataset's Features")
plt.show()

# %% [markdown]
# Five of the Unnamed columns are pratically full of null entries--this is a concern.

# %% [markdown]
# ### Filtering the Data

# %%
#Get the years of Year column and convert them to integers
academy_awards["Year"] = academy_awards["Year"].str[0:4].astype(int)

# %% [markdown]
# We select the rows that are after Year 2000 and call the dataframe _later than 2000_

# %%
later_than_2000 = academy_awards[academy_awards["Year"]>2000]

# %%
award_categories = ["Actor -- Leading Role",
"Actor -- Supporting Role",
"Actress -- Leading Role",
"Actress -- Supporting Role",]

# %%
nominations = later_than_2000[later_than_2000["Category"].isin(award_categories)]

# %%
nominations.head(3)
# Out:
#    Year               Category          Nominee  \
# 0  2010  Actor -- Leading Role    Javier Bardem
# 1  2010  Actor -- Leading Role     Jeff Bridges
# 2  2010  Actor -- Leading Role  Jesse Eisenberg
#
#                           Additional Info Won? Unnamed: 5 Unnamed: 6  \
# 0                      Biutiful {'Uxbal'}   NO        NaN        NaN
# 1           True Grit {'Rooster Cogburn'}   NO        NaN        NaN
# 2  The Social Network {'Mark Zuckerberg'}   NO        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN         NaN

# %% [markdown]
# ### Cleaning up _The Won?_ and _Unnamed_ Columns

# %% [markdown]
# We will transform the _Won?_ column to 0 and 1 boolean values and drop the null-ridden _Unnamed_ Columns

# %%
#Binary Entries for "Won?" column
replace_dict = { "YES": 1, "NO": 0 }
academy_awards["Won?"] = academy_awards["Won?"].map(replace_dict)

# %%
academy_awards["Won"] =academy_awards["Won?"]

# %%
drop_col_ls = ["Won?",
"Unnamed: 5",
"Unnamed: 6",
"Unnamed: 7",
"Unnamed: 8",
"Unnamed: 9",
"Unnamed: 10",]

# %%
#Drop the columns suggested from drop_col_ls list
final_academy_awards = academy_awards.drop(drop_col_ls, axis =1)

# %%
final_academy_awards
# Out:
#        Year                                        Category  \
# 0      2010                           Actor -- Leading Role
# 1      2010                           Actor -- Leading Role
# 2      2010                           Actor -- Leading Role
# 3      2010                           Actor -- Leading Role
# 4      2010                           Actor -- Leading Role
# 5      2010                        Actor -- Supporting Role
# 6      2010                        Actor -- Supporting Role
# 7      2010                        Actor -- Supporting Role
# 8      2010                        Actor -- Supporting Role
# 9      2010                        Actor -- Supporting Role
# 10     2010                         Actress -- Leading Role
# 11     2010                         Actress -- Leading Role
# 12     2010                         Actress -- Leading Role
# 13     2010                         Actress -- Leading Role
# 14     2010                         Actress -- Leading Role
# 15     2010                      Actress -- Supporting Role
# 16     2010                      Actress -- Supporting Role
# 17     2010                      Actress -- Supporting Role
# 18     2010                      Actress -- Supporting Role
# 19     2010                      Actress -- Supporting Role
# 20     2010                           Animated Feature Film
# 21     2010                           Animated Feature Film
# 22     2010                           Animated Feature Film
# 23     2010                                   Art Direction
# 24     2010                                   Art Direction
# 25     2010                                   Art Direction
# 26     2010                                   Art Direction
# 27     2010                                   Art Direction
# 28     2010                                  Cinematography
# 29     2010                                  Cinematography
# ...     ...                                             ...
# 10107  1927                                   Art Direction
# 10108  1927                                  Cinematography
# 10109  1927                                  Cinematography
# 10110  1927                                  Cinematography
# 10111  1927                                       Directing
# 10112  1927                                       Directing
# 10113  1927                                       Directing
# 10114  1927                                       Directing
# 10115  1927                                       Directing
# 10116  1927                                       Directing
# 10117  1927                                    Best Picture
# 10118  1927                                    Best Picture
# 10119  1927                                    Best Picture
# 10120  1927                                         Writing
# 10121  1927                                         Writing
# 10122  1927                                         Writing
# 10123  1927                                         Writing
# 10124  1927                                         Writing
# 10125  1927                                         Writing
# 10126  1927                                         Writing
# 10127  1927                                         Writing
# 10128  1927                                         Writing
# 10129  1927                                  Honorary Award
# 10130  1927                                  Honorary Award
# 10131  1927          Engineering Effects (archaic category)
# 10132  1927          Engineering Effects (archaic category)
# 19                Animal Kingdom {'Janine 'Smurf' Cody'}  0.0
# 20                        Chris Sanders and Dean DeBlois  0.0
# 21                                        Sylvain Chomet  0.0
# 22                                           Lee Unkrich  1.0
# 23     Production Design: Robert Stromberg; Set Decor...  1.0
# 24     Production Design: Stuart Craig; Set Decoratio...  0.0
# 25     Production Design: Guy Hendrix Dyas; Set Decor...  0.0
# 26     Production Design: Eve Stewart; Set Decoration...  0.0
# 27     Production Design: Jess Gonchor; Set Decoratio...  0.0
# 28                                     Matthew Libatique  0.0
# 29                                         Wally Pfister  1.0
# ...                                                  ...  ...
# 10107                                         7th Heaven  0.0
# 10108  The Devil Dancer; The Magic Flame; and Sadie T...  0.0
# 10109                                            Sunrise  1.0
# 10110                                            Sunrise  1.0
# 10111                                Two Arabian Knights  1.0
# 10112                                             Speedy  0.0
# 10113                                         7th Heaven  1.0
# 10114                                    Sorrell and Son  0.0
# 10115                                          The Crowd  0.0
# 10116                                                NaN  1.0
# 10117                                         The Racket  0.0
# 10118                                         7th Heaven  0.0
# 10119                                              Wings  1.0
# 10120                                    The Jazz Singer  0.0
# 10121                                     Glorious Betsy  0.0
# 10122                                         7th Heaven  1.0
# 10123                                   The Last Command  0.0
# 10124                                         Underworld  1.0
# 10125                  The Private Life of Helen of Troy  0.0
# 10126                                                NaN  1.0
# 10127                                                NaN  0.0
# 10128                                                NaN  1.0
# 10129                                                NaN  1.0
# 10130                                                NaN  1.0
# 10131                                                NaN  0.0
# 10132                                              Wings  1.0
# 10133                                                NaN  0.0
# 10134                                            Sunrise  1.0
# 10135                                          The Crowd  0.0
# 10136                                              Chang  0.0
#
# [10137 rows x 5 columns]

# %% [markdown]
# ### Cleaning Up the _Additional Info_ Column

# %%
additional_info_one = final_academy_awards["Additional Info"].str.rstrip("'}")

# %%
additional_info_two = additional_info_one.str.split(" {'")
movie_names = additional_info_two.str[0]
characters = additional_info_two.str[1]
final_academy_awards["Movie"] = movie_names
final_academy_awards["Character"] = characters
final_academy_awards = final_academy_awards.drop("Additional Info", axis=1)
final_academy_awards
# Out:
#        Year                                        Category  \
# 0      2010                           Actor -- Leading Role
# 1      2010                           Actor -- Leading Role
# 2      2010                           Actor -- Leading Role
# 3      2010                           Actor -- Leading Role
# 4      2010                           Actor -- Leading Role
# 5      2010                        Actor -- Supporting Role
# 6      2010                        Actor -- Supporting Role
# 7      2010                        Actor -- Supporting Role
# 8      2010                        Actor -- Supporting Role
# 9      2010                        Actor -- Supporting Role
# 10     2010                         Actress -- Leading Role
# 11     2010                         Actress -- Leading Role
# 12     2010                         Actress -- Leading Role
# 13     2010                         Actress -- Leading Role
# 14     2010                         Actress -- Leading Role
# 15     2010                      Actress -- Supporting Role
# 16     2010                      Actress -- Supporting Role
# 17     2010                      Actress -- Supporting Role
# 18     2010                      Actress -- Supporting Role
# 19     2010                      Actress -- Supporting Role
# 20     2010                           Animated Feature Film
# 21     2010                           Animated Feature Film
# 22     2010                           Animated Feature Film
# 23     2010                                   Art Direction
# 24     2010                                   Art Direction
# 25     2010                                   Art Direction
# 26     2010                                   Art Direction
# 27     2010                                   Art Direction
# 28     2010                                  Cinematography
# 29     2010                                  Cinematography
# 10131  Ralph Hammeras [NOTE: This nomination was not ...  0.0
# 10132                                        Roy Pomeroy  1.0
# 10133  Nugent Slaughter [NOTE: Though no specific tit...  0.0
# 10134                                                Fox  1.0
# 10135                                Metro-Goldwyn-Mayer  0.0
# 10136                             Paramount Famous Lasky  0.0
#
#                                                    Movie  \
# 0                                               Biutiful
# 1                                              True Grit
# 2                                     The Social Network
# 3                                      The King's Speech
# 4                                              127 Hours
# 5                                            The Fighter
# 6                                          Winter's Bone
# 7                                               The Town
# 8                                 The Kids Are All Right
# 9                                      The King's Speech
# 10                                The Kids Are All Right
# 11                                           Rabbit Hole
# 12                                         Winter's Bone
# 13                                            Black Swan
# 14                                        Blue Valentine
# 15                                           The Fighter
# 16                                     The King's Speech
# 17                                           The Fighter
# 18                                             True Grit
# 19                                        Animal Kingdom
# 20                        Chris Sanders and Dean DeBlois
# 21                                        Sylvain Chomet
# 22                                           Lee Unkrich
# 23     Production Design: Robert Stromberg; Set Decor...
# 24     Production Design: Stuart Craig; Set Decoratio...
# 25     Production Design: Guy Hendrix Dyas; Set Decor...
# 26     Production Design: Eve Stewart; Set Decoration...
# 27     Production Design: Jess Gonchor; Set Decoratio...
# 28                                     Matthew Libatique
# 29                                         Wally Pfister
# ...                                                  ...
# 10107                                         7th Heaven
# 10108  The Devil Dancer; The Magic Flame; and Sadie T...
# 10109                                            Sunrise
# 10110                                            Sunrise
# 10111                                Two Arabian Knights
# 10112                                             Speedy
# 10113                                         7th Heaven
# 10114                                    Sorrell and Son
# 10115                                          The Crowd
# 10116                                                NaN
# 10117                                         The Racket
# 10118                                         7th Heaven
# 10119                                              Wings
# 10120                                    The Jazz Singer
# 10121                                     Glorious Betsy
# 10122                                         7th Heaven
# 10123                                   The Last Command
# 10124                                         Underworld
# 10125                  The Private Life of Helen of Troy
# 10126                                                NaN
# 10127                                                NaN
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
# 10131                                                NaN
# 10132                                              Wings
# 10133                                                NaN
# 10134                                            Sunrise
# 10135                                          The Crowd
# 10136                                              Chang
#
#                         Character
# 0                           Uxbal
# 1                 Rooster Cogburn
# 2                 Mark Zuckerberg
# 3                  King George VI
# 4                    Aron Ralston
# 5                    Dicky Eklund
# 6                        Teardrop
# 7                  James Coughlin
# 8                            Paul
# 9                    Lionel Logue
# 10                            Nic
# 11                          Becca
# 12                            Ree
# 13     Nina Sayers/The Swan Queen
# 14                          Cindy
# 15               Charlene Fleming
# 16                Queen Elizabeth
# 17                     Alice Ward
# 18                    Mattie Ross
# 19            Janine 'Smurf' Cody
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                            NaN
# 24                            NaN
# 25                            NaN
# 26                            NaN
# 27                            NaN
# 28                            NaN
# 29                            NaN
# ...                           ...
# 10107                         NaN
# 10108                         NaN
# 10109                         NaN
# 10110                         NaN
# 10111                         NaN
# 10112                         NaN
# 10113                         NaN
# 10114                         NaN
# 10115                         NaN
# 10116                         NaN
# 10117                         NaN
# 10118                         NaN
# 10119                         NaN
# 10120                         NaN
# 10121                         NaN
# 10122                         NaN
# 10123                         NaN
# 10124                         NaN
# 10125                         NaN
# 10126                         NaN
# 10127                         NaN
# 10128                         NaN
# 10129                         NaN
# 10130                         NaN
# 10131                         NaN
# 10132                         NaN
# 10133                         NaN
# 10134                         NaN
# 10135                         NaN
# 10136                         NaN
#
# [10137 rows x 6 columns]

# %%
import sqlite3
